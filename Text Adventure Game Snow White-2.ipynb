# %%
"""
DocString:
                                          Introduction:

This game is based on the very first Disney movie: Snow White. 
However, what if we change a little bit the movie we currently know and decide how the story goes?

Here is a 4 minutes video that will enable you to refresh your chilhood memory: 
https://disney.fandom.com/wiki/Snow_White

The game consist in a win function in case Snow White is still alive at the end of the game, a fail function on the contrary and will consist in n stages:

- stage 1: The user has to find the phrase the Queen usually says
- stage 2: The user has to help the huntsman decide if he kills Snow White or not
- stage 3: The user has to decide if Snow White accept or refuses what the Queen wants to give her
- stage 4: The user will face two possible ends of the story depending on stage 3

Known bugs or errors:

Maybe it would have been interesting to help the user in the Trivia questions with hints
"""

#importing packages needed to run the game in a random way
from sys import exit
import random

# The function the_beginning will present the game
def the_beginning ():
    
    #starting to put the context of the situation about the game 
    print(""">>> If you are a Marvel fan you will know that we are living in one universe where Snow White 
        
                was a sweet little girl and the villain was her mother in law who poisonned her with an apple. 
                                        .............
                
                                                ..................
                            
                                                        ................
                                        
                                                                .....................
                                                    
                                                                       But What If none of that happened .... \n""")
    #making some space 
    print(" "*100)
    
    #asking for the user to press enter to continue the game
    input(prompt = "< Press enter to play >\n")#ask the user for action to continue.
    
    #making some space 
    print(" "*100)
    
    #changing the scene
    print("-"*100)#changing the scene
    
    #moving to the next stage for the user to play
    the_mirror()

#the first stage of the game starts where the user needs to find the Queen's famous phrase 
def the_mirror():
    
    #making some space 
    print(" "*100)
    
    #writing about the context of the evil queen
    print(""">>> Once upon a time, there lived a lovely little Princess named Snow White. 
        
            Her vain and wicked Stepmother the Queen feared that some day Snow White's beauty would surpass her own. 
        
            So she dressed the little Princess in rags and forced her to work as a Scullery Maid.""")
    
    #making some space 
    print(" "*100)
    
    #asking the user to press enter to continue the story
    input(prompt="< Press enter to continue >\n")
    
    #changing the scene
    print("-"*100)
    
    #making some space 
    print(" "*100)
    
    #explaining the rules of the game
    print(""">>> The Queen needs to formulate a question in order to talk to the Mirror. Could you help her to find it? 
          
                  The words are listed below but need to be put in the right order. 
                  
                                          < Find the phrase without putting any question mark >""")
    
    #list of the elements that make the famous phrase
    question_to_mirror = ["Magic","Mirror","on","the","wall","who","is","the","fairest","one", "of", "all"] #listing the phrase to shuffle it after and make the user to find it
    
    #miwing the words of the list
    mixed_words = random.shuffle(question_to_mirror) #mixing the words of the question with shuffle
    
    #printing a space before printing the list of words
    print(" "*100)
    
    #printing the list of words
    print(question_to_mirror)
    
    #before doing the while loop we want to stop it after 3 attempts and move to the next step for the user not to get stuck
    number_attempts = 3
    
    #the correct answer to find
    the_magic_mirror = "magic mirror on the wall who is the fairest one of all"
    
    #starting a loop for the user to find the phrase the queen says to the mirror on the wall
    #while loop of the number of attempts being positive
    while number_attempts >= 0:
        
        #starting a nested condition to stop the loop after 3 attempts
        #if the number of attempts are not equal to 0
        if number_attempts != 0:
            
            #making some space 
            print(" "*100)
            
            #asks for the user input
            phrase = input(prompt="Insert your answer (each word is not used more than once): ").casefold() #the casefold enable us to get rid of the capital letters
        
            #we start an if statement which enable us to compare the input of the user and the real answer
            #if the phrase written by the user is equal to the correct answer
            if phrase == the_magic_mirror:
            
                #if the answer is correct we continue the story
                print("\n>>> Congratulations! You find the correct answer! You rock! \U0001F60E Let's move to the next level!\n")
                
                #making some space 
                print(" "*100)
                
                #we change the scene
                print ("-"*100) #changing the scene
                
                #we take the user to the next stage
                huntsman_decision ()
                
                #finishing the while loop
                break
            
            #if the phrase written by the user is not equal to the correct answer
            elif phrase != the_magic_mirror:
            
                #removing one attempt
                number_attempts -= 1
            
                #print the number of attempt and some instructions to make sure why it is not working
                print("Wrong answer, please try again! Make sure you spell everything correctly")
                
                #printing a space before printing the list of words
                print(" "*100)
                
                #saying how many attempts does the user have
                print(f""" You still have {number_attempts} attempts remaining """)
        
            #in case there any issue with the code
            else: 
            
                #print that an error happened
                print("Something went wrong")
                
                #we take back the user we relaunch this function
                the_mirror()
        
        #if the number of attempt are equal to 0 this will happen
        elif number_attempts == 0:
            
            #removing one attempt
            number_attempts -= 1
            
            # Putting some space   
            print(" "*100)
            
            #Taking the user to the next stage even though she/he didn't find the solution but before giving the solution
            print("The correct answer is: Magic Mirror on the wall who is the fairest one of all ")
            
            #printing a space before printing the list of words
            print(" "*100)
            
            #informing to the user that it will go to the next level
            print("You will pass to the next level ")
            
            #making some space 
            print(" "*100)
            
            #changing the scene 
            print ("-"*100)
            
            #takes the user to the next stage any way as the person did its attempts
            huntsman_decision()
        
        #this happens in case something went wrong
        else:
            
            #print that an error happened
            print("Something went wrong")
            
            #we relaunch the same fucntion
            the_mirror()

#we come up to the next stage of the game where the user has to respond a trivia correctly for the hunter not to kill Snow White
def huntsman_decision():
    
    #making some space 
    print(" "*100)
    
    #the story continues for the pleasure of playing
    print("""\n>>> The Magic Mirror answers that Snow White is the fairest one. 
          
              The Queen filled with rage \U0001F525 orders the huntsman to take Snow White to the forest and to kill her! \n""")
    
    #imagining we are going to the forest
    print(('\U0001F332')*102)
        
    #printing a space before printing the list of words
    print(" "*100)
    
    #we continue with Snow White Story
    print(""">>>The Huntsman takes Snow White to the forest. 
    
            Before taking any decision, the huntsman comes to you to think of what to do.
            
                                (If the majority are well answered, Snow White lives)""")
    
    #we create a bank of questions; all related to Disney
    bank_question = ['What year did Disneyland open?',
                     'Who trained Hercules to be a hero?',
                     'Who is the fashion designer in The Incredibles?',
                    'What was the first Pixar movie?',
                    'Who was the first cartoon character to get a star on the Hollywood Walk of Fame?',
                    'Which Grammy winner composed the songs on the Tarzan soundtrack?']
    
    #bank of possible answers
    bank_answer = ["""Here are some options to help you:
                        a. 1955
                        b. 1956
                        c. 1957""",
                     """Here are some options to help you:
                        a. Paul
                        b. Patrick
                        c. Phil""",
                     """Here are some options to help you:
                        a. Erica
                        b. Edna
                        c. Eyra""",
                    """Here are some options to help you:
                        a. A Bug's Life
                        b. Toy Story
                        c. Monsters, Inc""",
                    """Here are some options to help you:
                        a. Mickey Mouse
                        b. Snow White
                        c. Donald Duck""",
                    """ Here are some options to help you:
                        a. Phil Collins
                        b. Elton John
                        c. Alan Menken"""]
    
    #list of the correct answer
    correct_answer = ["a. 1955", "c. phil", "b. edna", "b. toy story", "a. mickey mouse", "a. phil collins"] 
    
    #create a list to choose the index of the bank of questions
    generator = [0,1,2,3,4,5]
    
    #create the storage once one element of the generator is used
    storage = []
    
    #variables to count right answers
    right_answers = 0
    
    #variables to count wrong answers
    wrong_answers = 0
    
    #defining the number of questions we want to ask
    number_questions = 3
    
    #starting the while loop until the number of question asked is reached
    while number_questions > 0:
        
        #making some space
        print(" "*100)
        
        #take out one of the number
        number_questions -= 1
        
        #choose randomly the index
        index = random.choice(generator)
        
        #remove the index for the question not to be repeated
        generator.remove(index)
        
        #we store the index in another list in case we want to keep track of what is going on
        storage.append(index)
        
        #print the question
        print(bank_question[index])
        
        #making some space 
        print(" "*100)
        
        #print the possibilities of answer for this question  
        print(bank_answer[index])
        
        #making some space
        print(" "*100)
        
        #ask the user for the answer  
        answer = str(input(prompt="Please answer here: ")).casefold()
        
        #conditional statement to check the answer
        #if the user has the correct answer then we continue in this one
        if answer in correct_answer[index] and answer != " " and answer != "" and answer != "." and answer != ". ":
            
            #making some space
            print(" "*100)
            
            #printing the statement for the correct answer
            print("Correct!")
            
            #making some space 
            print(" "*100)
            
            #Adding a score for the right answer
            right_answers += 1
        
        #conditional if the answer is not the correct one
        elif answer not in correct_answer[index] or answer == " " or answer == "" or answer == "." or answer == ". ":
            
            #making some space
            print(" "*100)
            
            #printing the 
            print("Incorrect!")
            
            #making some space 
            print(" "*100)
            
            #adding a score for the wrong answer
            wrong_answers += 1
        
        #in case any problem arrives
        else:
            
            #making some space
            print(" "*100)
            
            #print something went wrong
            print("Something went wrong")
            
            #reboot this function
            huntsman_decision()
        
    #making some space 
    print(" "*100)
    
    #putting some space
    print("-"*100)
    
    #making some space 
    print(" "*100)
    
    #showing how many answers 
    print(f"""You had {right_answers} right answers and {wrong_answers} wrong answers """ )
    
    #putting some space
    print(" "*100)
    
    #making a conditional about right and wrong answers to define the path of the game
    #verifying if there is more right answers than wrong answers
    if wrong_answers < right_answers:
        #putting some space
        print(" "*100)
    
        #printing a congratulations statement
        print("""Congratulations! You had more right answers than wrong ones! You can go to the next step!""" )
        
        #sending the user to the next stage
        the_plan()
    
    #verifying if there is more wrong answers than right answers
    elif wrong_answers > right_answers:
        #putting some space
        print(" "*100)
    
        #printing fail statement
        print("""You had more wrong answers than right ones! """ )
        
        #sending the user to the fail 
        fail()
        
        #in case they want to repeat that stage to not start from the beginning
        huntsman_decision()
    
    #in case any issue happens with the code
    else:
        #putting some space
        print(" "*100)
        
        #printing that something went wrong
        print("Something went wrong")
        
        #rebooting the huntsman decision
        huntsman_decision()
        
#the evil Queen will know that Snow White is still alive and therefore Snow White needs to decide if she accept the gift or not
def the_plan():
    
    #making some space
    print(" "*100)
    
    #making the transfer to another scene
    print("-"*100)
    
    #putting some space
    print(" "*100)
    
    #putting the user into the context when Snow White runs into the forest
    print(""">>> 'Snow White runs into the forest scared for her life! The animals come and rescue her and bring her to the dwarf's house!
    
    """)
    
    #printing a bunch of animals
    print("""\U0001F98C \U0001F407 \U0001F43F \U0001F426 \U0001F989 \U0001F422 \U0001F98C \U0001F407 \U0001F43F \U0001F426 \U0001F989 \U0001F422""" * 9)
    
    #making some space
    print(" "*100)
    
    #printing the rest of the story where she meets the dwarfs
    print( """After a full day of work the dwarfs find Snow White sleeping in their bed. She explains to them the situation.
    
    Charmed by her black hair and her perfect skin, the dwarfs promise themselves to stand by her and that she could stay for as long as she needs.""")
    
    #making some space
    print(" "*100)
    
    #making the transfer to another scene
    print("-"*100)
    
    #putting some space
    print(" "*100)
    
    #continuing with the context of Snow White
    print(""">>> 'As part of the original story the wicked Queen changes her appearance and uses an apple to put Snow White into a deep sleep.
    
    But now you are the one who is in charge of the story, so you can decide her appearance and the weapon.""")
    
    #asking the user to choose the appearance of the queen when visiting Snow White
    appearance = input(prompt= "Choose the Queen appearance (insert a noun): ").casefold()
    
    #asking the user to choose the weapon of the queen 
    weapon = input(prompt= "Choose the killing element(insert a noun): ").casefold()
    
    #we want to do some space
    print(" "*100)
    
    #The answers provided above will be used in a f string to continue with the context
    print(f""" \n >>>'The Queen changes her appearance into {appearance} and decides to poison Snow White with {weapon}'.\n""")
    
    #we want to do some space
    print(" "*100)
    
    #We want to prepare the changing of the scene
    print("-"*100)#changing the scene
    
    #we want to do some space
    print(" "*100)
    
    #The plan of the evil Queen starts
    print(f""" \n >>>'The {appearance} arrives at the dwarf's house to see Snow White and offers {weapon} to Snow White'.\n""")
    
    #we want to do some space
    print(" "*100)
    
    #The user decides for Snow White
    print(f""" \n>>> What should Snow White do?
              1. Accept the {weapon} and have a taste of it
              2. Refuse the {weapon} and fight the {appearance} \n""")
    
    #we want to do some space
    print(" "*100)
    
    #the user decide what Snow White should do
    snow_white_decide = input(prompt = "Please answer here: ").casefold() #Snow White decision into prompt, holds user input
    #use of casefold to avoid comparing answers with capital letters to answers in lowercase
    
    #conditional statement based on user input
    #if Snow White accepts the killing element this happens
    if "1" in snow_white_decide or "accept" in snow_white_decide or "taste" in snow_white_decide:
        
        #we want to do some space
        print(" "*100)
        
        #printing the decision made by the user
        print(f""" \n>>> Snow White accepts the {weapon} and falls into a deep sleep.
        
                                Snow White can only wake up if she receives her Love's First Kiss""")
        
        #making some space
        print(" "*100)
        
        #changing the scene
        print("-"*100)#changing the scene
        
        #we move the user to the end of the story
        the_end()

    #if Snow White decides to fight this will happen 
    elif "2" in snow_white_decide or "refuse" in snow_white_decide or "fight" in snow_white_decide:
        
        #we want to do some space
        print(" "*100)
    
        #making the story funny with a little figth
        print(f""" \n>>> 'Snow White kills the {appearance}. While dying the Queen shows her face to Snow White.
        
                            Snow White needs to come back to her kingdom and show that everything is fine!""")
        
        #we want to do some space
        print(" "*100)
        
        #changing the scene
        print("-"*100)#changing the scene
        
        #We move the user to another type of end
        the_comeback()
        
    #in case something doesn't work properly
    else:
        #putting some space
        print(" "*100)
        
        #if the user put something that has nothing to do this will pop up
        print("Invalid command. Please try again.")
        
        #rebooting this function
        the_plan()

#this one of the possible ending of the game        
def the_comeback():
    
    #making some space
    print(" "*100)
    
    #painting the scene for the user to imagine it where Snow White wants to come back to the castle
    print("""Knowing that the evil Queen was dead; Snow White runs to the castle.
    
                However, before leaving the castle the Queen put a spell on it.
                
                        To break the spell Snow White needs to solve a question.
                        
                                But.... if she got it wrong she dies!""")
    #making some space
    print(" "*100)
    
    #making some space
    print("""Do you accept the challenge or do you want to go back to the previous stage and change the course of action?""")
    
    #making some space
    print(" "*100)
    
    #changing to a new scene
    print("-"*100)
    
    #creating the a bank of enigma
    bank_enigma = ["Mississippi has four S’s and four I’s. Can you spell that without using S or I?",
                  "Which letter of the alphabet has the most water?",
                  "What kind of ship has two mates but no captain?"]
    
    #having the correct answers predefined
    answers_enigma = ["that","c","friendship"]
    
    #having another set of correct answers in case someone answers relationship
    answers_enigma2 = ["that","c","relationship"]
    
    #putting some space
    print(" "*100)
    
    #asking for the user to answer
    decision = input(prompt = "Please answer here: ")

    #making some space
    print(" "*100)
    
    #conditional statement according to the user decision
    #in the case that Snow White accepts the challenge
    if "accept" in decision or "challenge" in decision or "y" in decision:
        
        #printing a little comment for the user
        print("You are very brave. Prepare yourself for this riddle.")
        
        #putting some space
        print(" "*100)
        
        #asking the user to choose a number between 0 and 2
        enigma_number = int(input(prompt = "Please choose an interger between 0 and 2 (0 and 2 included) <use numerics for the number; no strings>"))

        #we do a quick check that the user put an appropriate number
        #while the following is true this will happen
        while True:
        
            #if the number chosen is between 0 and 2 as properly asked before
            if enigma_number <= 2 and enigma_number >= 0:    
                
                #making some space
                print(" "*100)
                
                #the order matter if not any number would work
                print("We are ready to continue")
                
                #putting some space
                print(" "*100)
                
                #finishes the while statement
                break
        
            #if the number is negative and therefore not what was asked
            elif enigma_number < 0 :
            
                #making some space
                print(" "*100)
                
                #Asking the user to answer properly the answered previously asked
                print("""Ahahahah! You tried to trick me and check if another number would work but no!
                                
                                    Please insert the number properly!""")
            
                #putting some space
                print(" "*100)
                
                #asking the user to answer the previous question again
                enigma_number = int(input(prompt = "Please choose an interger between 0 and 2 (0 and 2 included) <use numerics for the number; no strings>"))
            
                #putting some space
                print(" "*100)
                
            #if the number is above 2 and therefore doesn't answer the question properly
            elif enigma_number > 2:
            
                #making some space
                print(" "*100)
                
                #good try on trying but no
                print("""Ahahahah! You tried to trick me and check if another number would work but no!
                                
                                    Please insert the number properly!""")
            
                #putting some space
                print(" "*100)
                
                #Ask the user for the input
                enigma_number = int(input(prompt = "Please choose an interger between 0 and 2 (0 and 2 included) <use numerics for the number; no strings>"))
            
            #in case anything wrong happens
            else:
            
                #making some space
                print(" "*100)
    
                #print that something went wrong
                print("Something went wrong!")
                
                #rebooting the function
                the_comeback()
        
        #making some space
        print(" "*100)
        
        #print the riddle
        print(bank_enigma[enigma_number])
        
        #making some space
        print(" "*100)
        
        #asking the user to put the answer 
        riddle = input(prompt = "Please answer here: <Do not separate the letters> ").lower()
        
        #doing a conditional statement to pick up the dilemna
        #if correct answered then this happens
        if riddle == answers_enigma[enigma_number] or riddle == answers_enigma2[enigma_number]:
                    
            #making some space
            print(" "*100)
                
            #congratulating the user
            print("Congratulations! The spell is broken!")
                
            #making some space
            print(" "*100)
                
            #sending the user to the winning part
            win()
        
        #if not correctly answer then this happens    
        elif riddle != answers_enigma[enigma_number] or riddle != answers_enigma2[enigma_number]:
                
            #making some space
            print(" "*100)
            
            #sorry you loose
            print("Ohohoh! You got it wrong!")
                
            #making some space
            print(" "*100)
                
            #sending the user to loosing function
            fail()
            
            #sending the user to replay the game
            the_beginning()
        
        #in case something bad happens
        else:
            #putting some space
            print(" "*100)    
            
            #print something went wrong
            print("Something went wrong!")
                
            #taking them back to the comeback function
            the_comeback()
    
    #if the user doesn't want to do the challenge then we take them to the previous stage   
    elif "go" in decision or "back" in decision or "previous" in decision or "change" in decision or "n" in decision:
        
        #making some space
        print(" "*100)
        
        #printing the statement
        print("It is ok we understand that your life depended from that! Let's go back to the previous stage!")
        
        #putting some space
        print(" "*100)
        
        #changing the scene
        print("-"*100)
                
        #taking them back to the previous stage
        the_plan()
    
    #in case something wrong happens    
    else:
        #putting some space
        print(" "*100)
        
        #printing that something went wrong
        print("Something went wrong")
        
        #taking them back to the comeback function
        the_comeback()

#that is another possible ending 
def the_end():
    
    #making some space
    print(" "*100)
    
    #continuing with the original story of Snow White
    print("""All the animals of the forest run to the dwarfs hoping they were not too late to save the Princess.
          
          Unfortunately the dwarfs arrived too late! They run after the Queen and see how she falls into the precipice. """)
    
    #making some space
    print(" "*100)
    
    #changing the scene
    print("-"*100)
    
    #putting some space
    print(" "*100)
    
    #continuing with the story
    print(""">>> ... So beautiful, even in death, that the dwarfs could not find it in their hearts to bury her.
        
            They fashioned a coffin of glass and gold, and kept eternal vigil at her side.
        
            The Prince, who had searched far and wide, heard of the maiden who slept in the glass coffin.""")
    
    #making some space
    print(" "*100)
    
    #changing the scene
    print("-"*100)
    
    #making some space
    print(" "*100)
    
    #continuing the story
    print("""Before kissing the Princess as in the original story... 
          
              ... The Prince needs to solve a calculation corectly for her to wake up 
              
                                          (She only wakes up if her Prince is smart)""")
    
    #Doing a list of mathematical calculations
    bank_calculations = ["11 * 12 + 13 - 62", "81 - 20 * 4 + 13 - 5","21 * 14 - 13 * 11 + 26", 
                         "25 * 31 - 60 * 7", "97 - 62 + 91 * 3"]
    
    #Doing a bank of answers that match the calculations
    bank_answers_calc = ["83", "9", "177", "355", "308" ]
    
    #list of generator number
    generator = [0, 1, 2, 3, 4]
    
    #Choosing an index randomly
    index_calc = random.choice(generator)
    
    #putting some space
    print(" "*100)
    
    #informing the user about the next step to do
    print("Please solve this problem")
    
    #making some space
    print(" "*100)
    
    #printing the question
    print(bank_calculations[index_calc])
    
    #making some space
    print(" "*100)
    
    #asking for the user the response
    answer_calc = str(input(prompt = "Please answer numerically here:"))
    
    #making some space
    print(" "*100)
    
    #conditional statement to check the solution of the user
    #if the user gave the correct answer
    if answer_calc == bank_answers_calc[index_calc]:
        
        #printing the winning statement
        print("""The Prince kisses Snow White and.............
                  
                  ..................................................
                  
                  ...............................................
                  
                  she comes out from the deep sleep the Queen put her in!""")
        
        #making some space
        print(" "*100)
        
        #changing the scene
        print("-"*100)
        
        #take the user to winning fucntion
        win()
    
    #if the user gave the wrong answer    
    elif answer_calc != bank_answers_calc[index_calc]:
            
        #printing the loosing statement
        print("""The Prince kisses Snow White and.............
                  
                  ..................................................
                  
                  ...............................................
                  
                  well nothing happens I guess the Prince wasn't smart enough!""")
        
        #making some space
        print(" "*100)
        
        #changing the scene
        print("-"*100)
        
        #takes the user to the failing function
        fail()
    
    #in case there is a problem    
    else:
        
        #print something went wrong
        print("Something went wrong")
        
        #rebooting the function
        the_end()
        
#defining the failing function        
def fail():
    
    #putting some space
    print(" "*100)
    
    #ending the game with a sad statement
    print(f""" Your decisions took Snow White to death! \U0001F62D \U0001F62D \U0001F62D \U0001F62D
                                
                                The entire kingdom is in pain for their loss! 
                                                            
                                                But most important of all you broke the Prince's heart \U0001F494 \U0001F494 \U0001F494!""")
    
    #putting some space
    print(" "*100)
    
    #asking the user if they want to play again
    play_again =  input(prompt = "Do you want to take another decision? <Please answer by Yes (or Y) or No (or N) >").casefold()
    
    #creating a conditional to verify if they want to play again
    #if the user does not want to play again
    if "n" in play_again:
        
        #making some space
        print(" "*100)
        
        #ending the game completely
        print("The End")
        
        #exiting the game
        exit()
    #if the user do want to play again
    elif "y" in play_again:
        
        #starting from the beginning
        print("Yeeeeiiiii time to play again")
        
        #pmaking some space
        print(" "*100)
        
        #game restart where the conditional statement send the user so it will depend on the function it is
        
    #in case any problem happens
    else:
        
        #print that something went wrong
        print("Something went wrong")
        
        #rebooting the fail function
        fail()
    
#definig the winning function    
def win():
    
    #putting some space
    print(" "*100)
    
    #printing the end of the game statement
    print(f"""Congratulations on passing each one of the stages successfully.
    
                    Snow White and the Prince lived happily ever after and very much in love! \U0001F499 """) 
    
    #putting some space
    print(" "*100)
    
    #printing all the love
    print(f"""\U0001F499 \U0001F499 \U0001F499 \U0001F499 \U0001F499 \U0001F499 \U0001F499 \U0001F499 """)
    
    #putting some space
    print(" "*100)
    
    #Asking if the user want to play again
    play_again = input(prompt = "Do you want to play again? <Please answer by Yes (or Y) or No (or N) >").casefold()
    
    #creating a conditional to verify if they want to play again
    #in case the user does not want to play again
    if "n" in play_again:
        
        #printing a space before printing the list of words
        print(" "*100)
        
        #ending the game completely
        print("End")
        
        #exiting the game
        exit()
    
    #in case the user does want to play again
    elif "y" in play_again:
        
        #starting from the beginning
        print("Yeeeeiiiii time to play again")
        
        #making some space
        print(" "*100)
        
        #changing the scene
        print("-"*100)
        
        #making some space
        print(" "*100)
        
        #game restart
        the_beginning()
    
    #in case of any error
    else:
        
        #print that something went wrong
        print("Something went wrong")
        
        #rebooting the fail function
        win()

the_beginning()
# Out:
# >>> If you are a Marvel fan you will know that we are living in one universe where Snow White
#
#                 was a sweet little girl and the villain was her mother in law who poisonned her with an apple.
#                                         .............
#
#                                                 ..................
#
#                                                         ................
#
#                                                                 .....................
#
#                                                                        But What If none of that happened ....
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/1r/wycwcw6n6ql7c9yfpc3lysmr0000gn/T/ipykernel_76492/551029941.py in <module>
#     992         win()
#     993
# --> 994 the_beginning()
#     995
#     996
#
# ...
